# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.21.6)

# %%
import cv2
photo = cv2.imread('/content/happygirl.jpg')

# %%
import time
start = time.time()

# %% [markdown]
# #Internal Mechanism of Model

# %%
gray = cv2.cvtColor(photo, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=604x602 at 0x7FCE4E790E80>

# %%
invert = cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=604x602 at 0x7FCE403A5190>

# %%
blur = cv2.GaussianBlur(invert, (15, 15), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=604x602 at 0x7FCE40333D00>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=604x602 at 0x7FCE403334C0>

# %%
sketch = cv2.divide(gray, invertblur, scale= 250.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=604x602 at 0x7FCE40333340>

# %%
from google.colab.patches import cv2_imshow
cv2.imwrite('output.png', sketch)
# Out:
# True

# %% [markdown]
# #For time taken calculation

# %%
end = time.time()
print(end-start)
# Out:
# 0.5385754108428955
